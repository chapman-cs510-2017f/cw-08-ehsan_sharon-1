# %%
from cplane_np_hw import julia, JuliaPlane

# %%
## Not using numba
# %time jp=JuliaPlane(1+1*1j)
jp.show()
# Out:
# CPU times: user 9.04 s, sys: 260 ms, total: 9.3 s
# Wall time: 10 s

# %%
## Using numba
# %time jp=JuliaPlane(1+1*1j)
jp.show()
# Out:
# CPU times: user 7 s, sys: 204 ms, total: 7.21 s
# Wall time: 7.59 s

# %%
## Conclusion
When creating a complex plane of size 20,000 X 20,000, numba saved us about 2 seconds of time.  When creating a complex plane of a larger size, it will continue to save us several seconds of time.
